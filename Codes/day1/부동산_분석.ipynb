# %%
import pandas as pd
import numpy as np
import sys
import os
sys.path.append(os.path.abspath(".."))
from module.encoder import MyEncoder
df = pd.read_csv('../../Datas/iM_data.csv', encoding='cp949')

# %%
df[df['업종_대분류'] == '부동산업']
# Out:
#           기준년월 업종_대분류 업종_중분류 사업장_시도 사업장_시군구 법인_고객등급 전담고객여부  요구불예금잔액  거치식예금잔액  \
# 45      202412   부동산업   부동산업  대구광역시      서구      일반      Y     0.01      0.0
# 46      202412   부동산업   부동산업  대구광역시      서구      일반      Y     0.00      0.0
# 47      202412   부동산업   부동산업  대구광역시      서구      일반      Y     0.64      0.0
# 48      202412   부동산업   부동산업  대구광역시      서구      일반      N     0.00      0.0
# 49      202412   부동산업   부동산업  대구광역시      서구      일반      Y     5.90      0.0
# ...        ...    ...    ...    ...     ...     ...    ...      ...      ...
# 347278  202203   부동산업   부동산업  대구광역시     수성구      일반      N   680.00      0.0
# 347285  202203   부동산업   부동산업  대구광역시     수성구      일반      Y     1.40      0.0
# 347290  202203   부동산업   부동산업   경상북도     영천시      일반      N    10.00      0.0
# 347291  202203   부동산업   부동산업   경상북도     경산시      일반      Y     3.40      0.0
# 347297  202203   부동산업   부동산업   경상북도     경주시      일반      Y    21.00      0.0
#
#         적립식예금잔액  ...  여신_시설자금대출좌수  신용카드개수  외환_수출실적거래건수  외환_수입실적거래건수  창구거래건수  \
# 45          0.0  ...           1개      0개           0건           0건      0건
# 46          0.0  ...           0개      1개           0건           0건      0건
# 47          0.0  ...           1개      0개           0건           0건      1건
# 48          0.0  ...           0개      1개           0건           0건      1건
# 49          0.0  ...           0개      0개           0건           0건      0건
# ...         ...  ...          ...     ...          ...          ...     ...
# 347278      0.0  ...           0개      1개           0건           0건      0건
# 347285      0.0  ...           2개      1개           0건           0건      0건
# 347290      0.0  ...           0개      1개           0건           0건      0건
# 347291      0.0  ...           1개      1개           0건           0건      0건
# 347297      0.0  ...    2개초과 5개이하      0개           0건           0건      2건
#
#           인터넷뱅킹거래건수    스마트뱅킹거래건수  폰뱅킹거래건수  ATM거래건수     자동이체거래건수
# 45               0건           1건       0건       0건   5건초과 10건이하
# 46               0건           0건       0건       0건           0건
# 47       5건초과 10건이하           2건       0건       0건   5건초과 10건이하
# 48               0건           1건       0건       0건  10건초과 20건이하
# 49               0건           0건       0건       0건  10건초과 20건이하
# ...             ...          ...      ...      ...          ...
# 347278  10건초과 20건이하           0건       0건       0건    2건초과 5건이하
# 347285           0건           0건       0건       0건    2건초과 5건이하
# 347290           0건  10건초과 20건이하       0건       0건           2건
# 347291           1건  20건초과 30건이하       0건       2건   5건초과 10건이하
# 347297    2건초과 5건이하           0건       0건       0건           0건
#
# [31749 rows x 45 columns]
